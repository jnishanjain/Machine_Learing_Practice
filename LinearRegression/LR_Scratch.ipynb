# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Setting up our random seed so out results are reproducable
np.random.seed(59)
X =  np.random.randint(1,10,(10000,1))
X.shape
# Out:
# (10000, 1)
