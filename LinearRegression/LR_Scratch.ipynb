# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
 #Setting up our random seed so out results are reproducable
np.random.seed(59)
X =  np.random.randint(1,10,(10000,2))
X.shape
# Out:
# (10000, 2)

# %%
weight_1 = 10
weight_2 = -5
bias = 10
y = X[:,0]*weight_1 + X[:,1]*weight_2 + bias
y.shape
# Out:
# (10000,)

# %%
# #Test
# T =  np.random.randint(1,10,(10,2))
# W = np.ones(T.shape[1])
# print(T.shape)
# print(T)
# print(W.shape)
# print(W)
# y = np.dot(T,W)
# print(y)
# print(y.shape)

# %%
class LinearRegression :
  def __init__(self,learning_rate=0.01,max_iterations = 1000):
    self.lr = learning_rate
    self.max_iter = max_iterations
    self.weights = None
    self.bias = None
    self.loss_history=[]

  def fit(self,X,y):
    n_samples,n_features = X.shape
    self.weights = np.zeros(n_features)
    self.bias = 0
    for epoch in range(self.max_iter):
      y_pred = self.predict(X)
      error = y_pred - y
      dw = 2/n_samples * np.dot(X.T,error)
      db = 2/n_samples * np.sum(error)
      self.weights = self.weights - self.lr*dw
      self.bias = self.bias - self.lr*db
      loss = np.mean(error**2)
      self.loss_history.append(loss)
      if epoch%100 == 0 :
        print(f"Epoch {epoch} : Loss {loss}")
  def predict(self,X):
     return np.dot(X,self.weights) + self.bias

# %%
model = LinearRegression(learning_rate=0.001,max_iterations=10000)
model.fit(X,y)
# Out:
# Epoch 0 : Loss 2096.8225
# Epoch 100 : Loss 60.82345182748473
# Epoch 200 : Loss 12.868120776315259
# Epoch 300 : Loss 9.209572630273117
# Epoch 400 : Loss 8.587008498273795
# Epoch 500 : Loss 8.18804320719906
# Epoch 600 : Loss 7.820285699572843
# Epoch 700 : Loss 7.469910597126605
# Epoch 800 : Loss 7.1352924251070755
# Epoch 900 : Loss 6.815667648927201
# Epoch 1000 : Loss 6.5103607092854
# Epoch 1100 : Loss 6.218729972668469
# Epoch 1200 : Loss 5.940162797137005
# Epoch 1300 : Loss 5.674074000979334
# Epoch 1400 : Loss 5.4199046167794975
# Epoch 1500 : Loss 5.177120716071005
# Epoch 1600 : Loss 4.945212287646822
# Epoch 1700 : Loss 4.723692166183927
# Epoch 1800 : Loss 4.512095008864657
# Epoch 1900 : Loss 4.309976317840487
# Epoch 2000 : Loss 4.116911506484418
# Epoch 2100 : Loss 3.9324950074705054
# Epoch 2200 : Loss 3.7563394208067797
# Epoch 2300 : Loss 3.5880747000319846
# Epoch 2400 : Loss 3.4273473748664807
# Epoch 2500 : Loss 3.2738198086844372
# Epoch 2600 : Loss 3.1271694892473874
# Epoch 2700 : Loss 2.987088351209372
# Epoch 2800 : Loss 2.853282128970297
# Epoch 2900 : Loss 2.72546973851816
# Epoch 3000 : Loss 2.60338268696162
# Epoch 3100 : Loss 2.4867645085123855
# Epoch 3200 : Loss 2.375370225732789
# Epoch 3300 : Loss 2.2689658349166204
# Epoch 3400 : Loss 2.167327814522341
# Epoch 3500 : Loss 2.070242655625883
# Epoch 3600 : Loss 1.9775064134068259
# Epoch 3700 : Loss 1.8889242787256095
# Epoch 3800 : Loss 1.804310168891996
# Epoch 3900 : Loss 1.7234863367648827
# Epoch 4000 : Loss 1.6462829973625488
# Epoch 4100 : Loss 1.5725379711987506
# Epoch 4200 : Loss 1.5020963435955939
# Epoch 4300 : Loss 1.434810139257417
# Epoch 4400 : Loss 1.3705380114220833
# Epoch 4500 : Loss 1.3091449449367227
# Epoch 4600 : Loss 1.2505019726341273
# Epoch 4700 : Loss 1.1944859044140708
# Epoch 4800 : Loss 1.1409790684603354
# Epoch 4900 : Loss 1.0898690640499504
# Epoch 5000 : Loss 1.0410485254352395
# Epoch 5100 : Loss 0.9944148963028234
# Epoch 5200 : Loss 0.9498702143356237
# Epoch 5300 : Loss 0.9073209054254163
# Epoch 5400 : Loss 0.8666775871036257
# Epoch 5500 : Loss 0.8278548807773581
# Epoch 5600 : Loss 0.7907712323763477
# Epoch 5700 : Loss 0.7553487410339749
# Epoch 5800 : Loss 0.7215129954424919
# Epoch 5900 : Loss 0.6891929175387127
# Epoch 6000 : Loss 0.6583206131917568
# Epoch 6100 : Loss 0.6288312295792376
# Epoch 6200 : Loss 0.6006628189522514
# Epoch 6300 : Loss 0.5737562085030022
# Epoch 6400 : Loss 0.5480548760616906
# Epoch 6500 : Loss 0.5235048313615284
# Epoch 6600 : Loss 0.5000545026224936
# Epoch 6700 : Loss 0.4776546282155434
# Epoch 6800 : Loss 0.45625815317969265
# Epoch 6900 : Loss 0.4358201303746296
# Epoch 7000 : Loss 0.4162976260611702
# Epoch 7100 : Loss 0.3976496297112164
# Epoch 7200 : Loss 0.3798369678577809
# Epoch 7300 : Loss 0.36282222180408363
# Epoch 7400 : Loss 0.34656964901884074
# Epoch 7500 : Loss 0.33104510805266735
# Epoch 7600 : Loss 0.31621598681782626
# Epoch 7700 : Loss 0.3020511340806934
# Epoch 7800 : Loss 0.2885207940229566
# Epoch 7900 : Loss 0.27559654373420617
# Epoch 8000 : Loss 0.26325123350449664
# Epoch 8100 : Loss 0.2514589297915035
# Epoch 8200 : Loss 0.2401948607424381
# Epoch 8300 : Loss 0.22943536415634677
# Epoch 8400 : Loss 0.2191578377773974
# Epoch 8500 : Loss 0.2093406918147721
# Epoch 8600 : Loss 0.1999633035894425
# Epoch 8700 : Loss 0.1910059742125191
# Epoch 8800 : Loss 0.18244988720420455
# Epoch 8900 : Loss 0.17427706896638448
# Epoch 9000 : Loss 0.1664703510258684
# Epoch 9100 : Loss 0.15901333396891867
# Epoch 9200 : Loss 0.15189035299133816
# Epoch 9300 : Loss 0.14508644499172876
# Epoch 9400 : Loss 0.13858731713882272
# Epoch 9500 : Loss 0.1323793168468024
# Epoch 9600 : Loss 0.12644940309561103
# Epoch 9700 : Loss 0.1207851190359305
# Epoch 9800 : Loss 0.11537456582134487
# Epoch 9900 : Loss 0.11020637761265684

# %%
print("Orignal Weights")
print(f"Weight 1 : {weight_1} , Weight 2 : {weight_2}")
print("Predicted Weights")
print(f"Weight 1 : {model.weights[0]}, Weight 2 : {model.weights[1]}")
print("Orignal Bias")
print(f"Bias : {bias}")
print("Predicted Bias")
print(model.bias)
# Out:
# Orignal Weights
# Weight 1 : 10 , Weight 2 : -5
# Predicted Weights
# Weight 1 : 10.084100855539932, Weight 2 : -4.916870360227355
# Orignal Bias
# Bias : 10
# Predicted Bias
# 9.04872570967173
